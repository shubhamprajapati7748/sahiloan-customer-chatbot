# %% [markdown]
# ### Claude Code
#
# https://claude.ai/share/1e4cbe56-c26b-44fd-991a-ef23fe34a21a

# %%
# !poetry add PyPDF2 pypdf pdfplumber pymupdf unstructured
# Out:
# The following packages are already present in the pyproject.toml and will be skipped:
#
#   - PyPDF2
#   - pypdf
#   - pdfplumber
#   - pymupdf
#
# If you want to update it to the latest compatible version, you can use `poetry update package`.
# If you prefer to upgrade it to the latest available version, you can use `poetry add package@latest`.
#
# Using version ^0.18.31 for unstructured
#
# Updating dependencies
# Resolving dependencies... (0.5s)
#
# Package operations: 14 installs, 0 updates, 0 removals
#
#   - Installing llvmlite (0.34.0): Pending...
#   - Installing llvmlite (0.34.0): Building a wheel file for llvmlite for Python 3.13.7 on darwin-arm64
#   - Installing llvmlite (0.34.0): Failed
#
# PEP517 build of a dependency failed
#
# Backend subprocess exited when trying to invoke build_wheel
#
# ...

# %%
# !poetry add python-docx pytesseract pillow pandas numpy pydantic jsonschema python-dateutil
# Out:
# The following packages are already present in the pyproject.toml and will be skipped:
#
#   - python-docx
#   - pydantic
#   - python-dateutil
#
# If you want to update it to the latest compatible version, you can use `poetry update package`.
# If you prefer to upgrade it to the latest available version, you can use `poetry add package@latest`.
#
# Using version ^0.3.13 for pytesseract
# Using version ^12.1.0 for pillow
# Using version ^3.0.0 for pandas
# Using version ^2.4.1 for numpy
# Using version ^4.26.0 for jsonschema
#
# Updating dependencies
# Resolving dependencies... (0.0s)
#
# The current project's supported Python range (>=3.10,<3.14) is not compatible with some of the required packages Python requirement:
#   - numpy requires Python >=3.11, so it will not be installable for Python >=3.10,<3.11
#
# Because numpy (2.4.1) requires Python >=3.11
#  and no versions of numpy match >2.4.1,<3.0.0, numpy is forbidden.
# ...

# %%
from sahiloan_chatbot.application.ocr_pipeline.integration import process_cibil_report_pipeline

# %%
import json

# Example usage
result = process_cibil_report_pipeline(
    file_path="/Users/shubhamprajapati/Desktop/sahiloan/sahiloan-customer-chatbot/docs/cibils/Govindnarayan.pdf",
    output_dir="/Users/shubhamprajapati/Desktop/sahiloan/sahiloan-customer-chatbot/docs/output",
)

print("\n=== Summary ===")
print(json.dumps(result["summary"], indent=2))

print("\n=== Risk Indicators ===")
print(json.dumps(result["risk_indicators"], indent=2))

print("\n=== Account Summary ===")
print(json.dumps(result["account_summary"], indent=2))
# Out:
# Loading document: /Users/shubhamprajapati/Desktop/sahiloan/sahiloan-customer-chatbot/docs/cibils/Govindnarayan.pdf
# Processing document...
# Saving parsed data to: /Users/shubhamprajapati/Desktop/sahiloan/sahiloan-customer-chatbot/docs/output/cibil_report_parsed.json
# Generating summary...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 4
#       1 import json
#       3 # Example usage
# ----> 4 result = process_cibil_report_pipeline(
#       5     file_path="/Users/shubhamprajapati/Desktop/sahiloan/sahiloan-customer-chatbot/docs/cibils/Govindnarayan.pdf",
#       6     output_dir="/Users/shubhamprajapati/Desktop/sahiloan/sahiloan-customer-chatbot/docs/output",
#       7 )
#       9 print("\n=== Summary ===")
#      10 print(json.dumps(result["summary"], indent=2))
#
# ...
